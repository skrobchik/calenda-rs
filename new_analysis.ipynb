# %%
import json
import matplotlib.pyplot as plt
import pickle
with open('simulation_results_2024-04-09T041752.pickle', mode='br') as f:
    data = pickle.load(f)

# %%
fig, ax = plt.subplots(dpi=100)
for i in range(len(data)):
    final_cost = data[i]['final_cost']
    steps = data[i]['total_steps']
    curr_cost = data[i]['stats']['curr_cost']
    ax.plot(curr_cost, label=f'{steps} steps (final_cost = {final_cost})')
ax.legend(fontsize=5)
ax.set_title('curr_cost')
ax.set_xlabel('x')
ax.set_ylabel('cost')
ax.set_yscale('log')
# ax.set_xscale('log')

# %%
fig, ax = plt.subplots()
x = [data[i]['total_steps'] for i in range(len(data)-10, len(data))]
y = [data[i]['final_cost'] for i in range(len(data)-10, len(data))]
ax.plot(x, y)
ax.set_xlabel('Num. Simulation Steps')
ax.set_ylabel('Final Cost')
ax.set_title('Simulation steps vs Final Cost')
# ax.set_yscale('log')
# ax.set_xscale('log')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 fig, ax = plt.subplots()
# ----> 2 x = [data[i]['total_steps'] for i in range(len(data)-10, len(data))]
#       3 y = [data[i]['final_cost'] for i in range(len(data)-10, len(data))]
#       4 ax.plot(x, y)
#
# Cell In[15], line 2, in <listcomp>(.0)
#       1 fig, ax = plt.subplots()
# ----> 2 x = [data[i]['total_steps'] for i in range(len(data)-10, len(data))]
#       3 y = [data[i]['final_cost'] for i in range(len(data)-10, len(data))]
#       4 ax.plot(x, y)
#
# IndexError: list index out of range

# %%
fig, ax = plt.subplots()
final_cost = data[-1]['final_cost']
steps = data[-1]['total_steps']
curr_cost = data[-1]['stats']['curr_cost']
temperature = data[-1]['stats']['temperature']
ax.plot(temperature, label=f'{steps} steps (final_cost = {final_cost})')
ax.legend()
ax.set_title('curr_cost')
ax.set_xlabel('x')
ax.set_ylabel('cost')
